# %%
# spark.sql("""
#     CREATE TABLE IF NOT EXISTS SupplyChain_Lakehouse.dbo.utl_pipeline_metadata (
#         table_name            STRING,
#         last_watermark_value  STRING,
#         last_load_date        TIMESTAMP,
#         rows_loaded           LONG,
#         rows_rejected         LONG,
#         status                STRING,
#         error_message         STRING,
#         pipeline_notes        STRING
#     )
#     USING DELTA
# """)

# print("Done! utl_pipeline_metadata created.")
# Out:
# StatementMeta(, db95995a-a2a1-4ded-bb15-b112dd286897, 3, Finished, Available, Finished, False)
# Done! utl_pipeline_metadata created.

# %%
df = spark.sql("""
    SELECT MAX(dfcSnapshot) AS max_wm
    FROM SupplyChain_Lakehouse.dbo.brz_SupplyChain_Enh_1__DemandForecastSnapshotDaily
""")

display(df)
# Out:
# StatementMeta(, db95995a-a2a1-4ded-bb15-b112dd286897, 4, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 8e963138-c70c-44d5-a568-99572c35b9e5)

# %%
# Lấy max watermark từ bảng đã load sẵn
result = spark.sql("""
    SELECT MAX(dfcSnapshot) AS max_wm
    FROM SupplyChain_Lakehouse.dbo.brz_SupplyChain_Enh_1__DemandForecastSnapshotDaily
""").collect()

max_wm = result[0]["max_wm"]
print(f"Max watermark hiện tại: {max_wm}")

# Insert record vào metadata
spark.sql(f"""
    INSERT INTO SupplyChain_Lakehouse.dbo.utl_pipeline_metadata
    VALUES (
        'brz_SupplyChain_Enh_1__DemandForecastSnapshotDaily',
        '{max_wm}',
        current_timestamp(),
        NULL,
        0,
        'success',
        NULL,
        'Seeded manually - full load done before pipeline setup'
    )
""")

print(f"Done! Watermark seeded: {max_wm}")
# Out:
# StatementMeta(, db95995a-a2a1-4ded-bb15-b112dd286897, 5, Finished, Available, Finished, False)
# Max watermark hiện tại: 2026-02-24 00:00:00
# Done! Watermark seeded: 2026-02-24 00:00:00
